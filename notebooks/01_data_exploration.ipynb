# %% [markdown]
# # Data Exploration
#
# Explore class distribution, view sample images, and check for class imbalance before training.

# %%
import sys
sys.path.append('../src')

from dataset import get_dataloaders

train_loader, val_loader, test_loader, classes = get_dataloaders('../data/processed')
print('Classes:', classes)
print('Train batches:', len(train_loader))
