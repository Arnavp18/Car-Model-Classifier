# %% [markdown]
# # Model Experiments
#
# Compare baseline CNN vs. ResNet18 transfer learning, plot learning curves, and try alternative architectures (MobileNetV3, EfficientNet-B0).

# %%
import sys
sys.path.append('../src')

from dataset import get_dataloaders
from train import build_model, run_epoch

# Load data and experiment with different models/hyperparameters here.
